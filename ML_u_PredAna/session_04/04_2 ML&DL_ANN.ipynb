# %% [markdown]
# The MAGIC Gamma Telescope dataset is a binary tabular classification dataset with 19,020 samples and 10 numerical features, used to classify events as gamma or hadron.
#
# https://archive.ics.uci.edu/dataset/159/magic+gamma+telescope
